# %%
# %pip install databricks-sdk python-dotenv --quiet
dbutils.library.restartPython()

# %%
# %sh
export DATABRICKS_HOST="https://dbc-825edb48-78cb.cloud.databricks.com"
export DATABRICKS_TOKEN="<REDACTED_USE_ENV_OR_SECRET>"
export DATABRICKS_JOB_ID="315227620491909"

cd /Workspace/Users/kostia6@gmail.com/databricks-assignment/Lab\ 9
python pipeline_runner.py
